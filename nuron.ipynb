# %%
import numpy as np
import matplotlib.pyplot as plt
w0=float(input('initiate first weight:\n '))
w1=float(input('initiate first weight:\n '))
p=[[-1,1],[-2,2],[-3,3],[-0.4,0.1],[-0.1,3],[-1,0.5]]
n=[[1,-1],[2,-2],[3,-3],[4,0.1],[0.1,-3],[1,-0.5]]
array=[p,n]
print(array)

p1=[array[0][0][0],array[0][1][0],array[0][2][0],array[0][3][0],array[0][4][0],array[0][5][0]]
p2=[array[0][0][1],array[0][1][1],array[0][2][1],array[0][3][1],array[0][4][1],array[0][5][1]]
n1=[array[1][0][0],array[1][1][0],array[1][2][0],array[1][3][0],array[1][4][0],array[1][5][0]]
n2=[array[1][0][1],array[1][1][1],array[1][2][1],array[1][3][1],array[1][4][1],array[1][5][1]]

w=[w0,w1]

x=np.arange(-5,5,1)
plt.scatter(p1,p2)
plt.scatter(n1,n2)
m=w[1]/w[0]

plt.plot(x,-1/m*x)
plt.show
# Out:
# initiate first weight:
#  1
# initiate first weight:
#  1
# [[[-1, 1], [-2, 2], [-3, 3], [-0.4, 0.1], [-0.1, 3], [-1, 0.5]], [[1, -1], [2, -2], [3, -3], [4, 0.1], [0.1, -3], [1, -0.5]]]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(p1,p2)
plt.scatter(n1,n2)
for num in range(1000):
    print(w)
    m=w[1]/w[0]
    
    plt.plot(x,-1/m*x)

    for i in range(len(array)):
        for j in range(len(p)):
            sum=array[i][j][0]*w[0]+array[i][j][1]*w[1]
            
            if i==0 and sum<0:
#                 print('hii')
                     
#                 w[0]=w[0]+0.1*sum
#                 w[1]=w[1]+0.1*sum
                w[0]=w[0]+0.5*(array[i][j][0]-w[0])
                w[1]=w[1]+0.5*(array[i][j][1]-w[1])
                    
                    
            if i==1 and sum>=0:
                w[0]=w[0]+0.5*(array[i][j][0]-w[0])
                w[1]=w[1]+0.5*(array[i][j][1]-w[1])
                                    
                
#                 print('bye')
#                 w[0]=w[0]-0.1*sum
#                 w[1]=w[1]-0.1*sum 
                    
            
            
print(w) 
# x=np.arange(-5,5,1)
# m=w[1]/w[0]
# plt.plot(x,-m*x)
plt.show
# Out:
# [1.0, 1.0]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# [-0.35, 0.525]
# ...
